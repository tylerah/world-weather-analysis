# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Generate Random Coordinates & Retrieve Nearest City

# %%
# import citipy and random module
import random
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# create the list for holding the cities
cities = []

# identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if the city is unique, then add it to the cities list
    if city not in cities:
        cities.append(city)
        
# print the city count to confirm sufficient count
len(cities)
# Out:
# 748

# %% [markdown]
# ## Perform API Call with OpenWeatherMap

# %%
# import API Key and dependencies
import requests
from config import weather_api_key
import time

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# create list to store retrieved data
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

# set counters
record_count = 1
set_count = 1

# loop to iterate through cities list
for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nikolskoye
# Processing Record 2 of Set 1 | portland
# Processing Record 3 of Set 1 | galgani
# City not found. Skipping...
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | sabak
# Processing Record 6 of Set 1 | walvis bay
# Processing Record 7 of Set 1 | zhigansk
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | mihai viteazu
# Processing Record 10 of Set 1 | vestmannaeyjar
# Processing Record 11 of Set 1 | nome
# Processing Record 12 of Set 1 | alta floresta
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | palana
# Processing Record 15 of Set 1 | novyy buyan
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | sadiqabad
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | gisborne
# Processing Record 20 of Set 1 | thompson
# Processing Record 21 of Set 1 | georgetown
# Processing Record 22 of Set 1 | saskylakh
# Processing Record 23 of Set 1 | vao
# Processing Record 24 of Set 1 | shimoda
# Processing Record 25 of Set 1 | coahuayana
# Processing Record 26 of Set 1 | cherskiy
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | constitucion
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | sitka
# Processing Record 31 of Set 1 | okhotsk
# Processing Record 32 of Set 1 | sorong
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | hasaki
# Processing Record 37 of Set 1 | qaanaaq
# Processing Record 38 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 1 | karamea
# City not found. Skipping...
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | kavieng
# Processing Record 42 of Set 1 | komsomolskiy
# Processing Record 43 of Set 1 | port blair
# Processing Record 44 of Set 1 | tessalit
# Processing Record 45 of Set 1 | road town
# Processing Record 46 of Set 1 | huarmey
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | port keats
# Processing Record 49 of Set 1 | otane
# Processing Record 50 of Set 1 | mahebourg
# Processing Record 1 of Set 2 | lavrentiya
# Processing Record 2 of Set 2 | east london
# Processing Record 3 of Set 2 | ormara
# Processing Record 4 of Set 2 | cabo san lucas
# Processing Record 5 of Set 2 | soyo
# Processing Record 6 of Set 2 | santa cruz
# Processing Record 7 of Set 2 | westport
# Processing Record 8 of Set 2 | tura
# Processing Record 9 of Set 2 | puerto el triunfo
# Processing Record 10 of Set 2 | lata
# Processing Record 11 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | comodoro rivadavia
# Processing Record 14 of Set 2 | bosobolo
# Processing Record 15 of Set 2 | roald
# Processing Record 16 of Set 2 | tunduru
# City not found. Skipping...
# Processing Record 17 of Set 2 | bossier city
# Processing Record 18 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 2 | guarapari
# Processing Record 20 of Set 2 | una
# Processing Record 21 of Set 2 | erenhot
# Processing Record 22 of Set 2 | darhan
# Processing Record 23 of Set 2 | klaksvik
# Processing Record 24 of Set 2 | biak
# Processing Record 25 of Set 2 | kenai
# Processing Record 26 of Set 2 | katsuura
# Processing Record 27 of Set 2 | dickinson
# Processing Record 28 of Set 2 | carnarvon
# Processing Record 29 of Set 2 | moelv
# Processing Record 30 of Set 2 | upernavik
# Processing Record 31 of Set 2 | bredasdorp
# Processing Record 32 of Set 2 | maputo
# Processing Record 33 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 34 of Set 2 | serenje
# Processing Record 35 of Set 2 | vanavara
# Processing Record 36 of Set 2 | grindavik
# Processing Record 37 of Set 2 | chuy
# Processing Record 38 of Set 2 | jiazi
# Processing Record 39 of Set 2 | belyy yar
# Processing Record 40 of Set 2 | haines junction
# Processing Record 41 of Set 2 | dingle
# Processing Record 42 of Set 2 | ancud
# Processing Record 43 of Set 2 | fallon
# Processing Record 44 of Set 2 | caravelas
# Processing Record 45 of Set 2 | bethel
# Processing Record 46 of Set 2 | yellowknife
# Processing Record 47 of Set 2 | jalu
# Processing Record 48 of Set 2 | port alfred
# Processing Record 49 of Set 2 | hilo
# Processing Record 50 of Set 2 | finnsnes
# Processing Record 1 of Set 3 | anahuac
# Processing Record 2 of Set 3 | touros
# Processing Record 3 of Set 3 | kalmunai
# Processing Record 4 of Set 3 | hithadhoo
# Processing Record 5 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 3 | igarka
# Processing Record 7 of Set 3 | hermanus
# Processing Record 8 of Set 3 | chake chake
# Processing Record 9 of Set 3 | norman wells
# Processing Record 10 of Set 3 | lompoc
# Processing Record 11 of Set 3 | bluff
# Processing Record 12 of Set 3 | karratha
# Processing Record 13 of Set 3 | prince rupert
# Processing Record 14 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 3 | trebur
# Processing Record 17 of Set 3 | yarega
# Processing Record 18 of Set 3 | calama
# Processing Record 19 of Set 3 | mandurah
# Processing Record 20 of Set 3 | butaritari
# Processing Record 21 of Set 3 | vila
# Processing Record 22 of Set 3 | puerto ayora
# Processing Record 23 of Set 3 | kamenka
# Processing Record 24 of Set 3 | luderitz
# Processing Record 25 of Set 3 | bilibino
# Processing Record 26 of Set 3 | arraial do cabo
# Processing Record 27 of Set 3 | kapaa
# Processing Record 28 of Set 3 | vila velha
# Processing Record 29 of Set 3 | aripuana
# Processing Record 30 of Set 3 | paamiut
# Processing Record 31 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 3 | olinda
# Processing Record 33 of Set 3 | dikson
# Processing Record 34 of Set 3 | kedrovyy
# Processing Record 35 of Set 3 | itarema
# Processing Record 36 of Set 3 | independencia
# Processing Record 37 of Set 3 | tuatapere
# Processing Record 38 of Set 3 | nishihara
# Processing Record 39 of Set 3 | saryg-sep
# Processing Record 40 of Set 3 | hamilton
# Processing Record 41 of Set 3 | salalah
# Processing Record 42 of Set 3 | kruisfontein
# Processing Record 43 of Set 3 | port augusta
# Processing Record 44 of Set 3 | aklavik
# Processing Record 45 of Set 3 | laguna
# Processing Record 46 of Set 3 | hobart
# Processing Record 47 of Set 3 | iqaluit
# Processing Record 48 of Set 3 | esperance
# Processing Record 49 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 3 | tilichiki
# Processing Record 1 of Set 4 | kaitangata
# Processing Record 2 of Set 4 | bilma
# Processing Record 3 of Set 4 | tocopilla
# Processing Record 4 of Set 4 | ahipara
# Processing Record 5 of Set 4 | aguas vermelhas
# Processing Record 6 of Set 4 | genc
# Processing Record 7 of Set 4 | bar harbor
# Processing Record 8 of Set 4 | eureka
# Processing Record 9 of Set 4 | mehamn
# Processing Record 10 of Set 4 | camacha
# Processing Record 11 of Set 4 | knyaze-volkonskoye
# Processing Record 12 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 4 | dzhebariki-khaya
# Processing Record 14 of Set 4 | avarua
# Processing Record 15 of Set 4 | kieta
# Processing Record 16 of Set 4 | conde
# Processing Record 17 of Set 4 | burica
# City not found. Skipping...
# Processing Record 18 of Set 4 | kirakira
# Processing Record 19 of Set 4 | we
# City not found. Skipping...
# Processing Record 20 of Set 4 | ust-maya
# Processing Record 21 of Set 4 | santa cruz cabralia
# Processing Record 22 of Set 4 | aswan
# Processing Record 23 of Set 4 | gryazi
# Processing Record 24 of Set 4 | umm lajj
# Processing Record 25 of Set 4 | souillac
# Processing Record 26 of Set 4 | airai
# Processing Record 27 of Set 4 | sao filipe
# Processing Record 28 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 4 | surt
# Processing Record 30 of Set 4 | sao joao da barra
# Processing Record 31 of Set 4 | angoche
# Processing Record 32 of Set 4 | domna
# Processing Record 33 of Set 4 | kahului
# Processing Record 34 of Set 4 | tiksi
# Processing Record 35 of Set 4 | rafraf
# Processing Record 36 of Set 4 | castro
# Processing Record 37 of Set 4 | itaituba
# Processing Record 38 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 4 | leningradskiy
# Processing Record 40 of Set 4 | kailua
# Processing Record 41 of Set 4 | arak
# Processing Record 42 of Set 4 | moroni
# Processing Record 43 of Set 4 | howard springs
# Processing Record 44 of Set 4 | saint george
# Processing Record 45 of Set 4 | qasigiannguit
# Processing Record 46 of Set 4 | presidencia roque saenz pena
# Processing Record 47 of Set 4 | praia da vitoria
# Processing Record 48 of Set 4 | natalio
# Processing Record 49 of Set 4 | byron bay
# Processing Record 50 of Set 4 | ilulissat
# Processing Record 1 of Set 5 | mercedes
# Processing Record 2 of Set 5 | dongsheng
# Processing Record 3 of Set 5 | svetlogorsk
# Processing Record 4 of Set 5 | provideniya
# Processing Record 5 of Set 5 | babu
# Processing Record 6 of Set 5 | necochea
# Processing Record 7 of Set 5 | stephenville
# Processing Record 8 of Set 5 | port lincoln
# Processing Record 9 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 5 | kerman
# Processing Record 11 of Set 5 | bambous virieux
# Processing Record 12 of Set 5 | dong hoi
# Processing Record 13 of Set 5 | pacific grove
# Processing Record 14 of Set 5 | det udom
# Processing Record 15 of Set 5 | vestmanna
# Processing Record 16 of Set 5 | khatanga
# Processing Record 17 of Set 5 | te anau
# Processing Record 18 of Set 5 | jiangyou
# Processing Record 19 of Set 5 | luganville
# Processing Record 20 of Set 5 | saldanha
# Processing Record 21 of Set 5 | belmonte
# Processing Record 22 of Set 5 | mount gambier
# Processing Record 23 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 5 | kajaani
# Processing Record 25 of Set 5 | baykit
# Processing Record 26 of Set 5 | usinsk
# Processing Record 27 of Set 5 | marawi
# Processing Record 28 of Set 5 | la orilla
# Processing Record 29 of Set 5 | pedernales
# Processing Record 30 of Set 5 | colesberg
# Processing Record 31 of Set 5 | samarai
# Processing Record 32 of Set 5 | port elizabeth
# Processing Record 33 of Set 5 | bozuyuk
# Processing Record 34 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 35 of Set 5 | elizabeth city
# Processing Record 36 of Set 5 | tottori
# Processing Record 37 of Set 5 | hami
# Processing Record 38 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 5 | praia
# Processing Record 40 of Set 5 | maxixe
# Processing Record 41 of Set 5 | kodiak
# Processing Record 42 of Set 5 | hirado
# Processing Record 43 of Set 5 | evensk
# Processing Record 44 of Set 5 | thunder bay
# Processing Record 45 of Set 5 | jinchengjiang
# City not found. Skipping...
# Processing Record 46 of Set 5 | pafos
# Processing Record 47 of Set 5 | susanville
# Processing Record 48 of Set 5 | kununurra
# Processing Record 49 of Set 5 | rocha
# Processing Record 50 of Set 5 | hobyo
# Processing Record 1 of Set 6 | labuhan
# Processing Record 2 of Set 6 | faanui
# Processing Record 3 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 6 | mahendranagar
# Processing Record 5 of Set 6 | husavik
# Processing Record 6 of Set 6 | ambilobe
# Processing Record 7 of Set 6 | havre-saint-pierre
# Processing Record 8 of Set 6 | yuli
# Processing Record 9 of Set 6 | zhuhai
# Processing Record 10 of Set 6 | kismayo
# Processing Record 11 of Set 6 | saint anthony
# Processing Record 12 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 6 | tonota
# Processing Record 14 of Set 6 | kapit
# Processing Record 15 of Set 6 | verdun
# Processing Record 16 of Set 6 | luena
# Processing Record 17 of Set 6 | broome
# Processing Record 18 of Set 6 | sinnamary
# Processing Record 19 of Set 6 | cayenne
# Processing Record 20 of Set 6 | inta
# Processing Record 21 of Set 6 | benguela
# Processing Record 22 of Set 6 | yatou
# Processing Record 23 of Set 6 | semporna
# Processing Record 24 of Set 6 | kushmurun
# Processing Record 25 of Set 6 | fortuna
# Processing Record 26 of Set 6 | mnogovershinnyy
# Processing Record 27 of Set 6 | severo-kurilsk
# Processing Record 28 of Set 6 | ugoofaaru
# Processing Record 29 of Set 6 | saint-philippe
# Processing Record 30 of Set 6 | lagoa
# Processing Record 31 of Set 6 | ribeira grande
# Processing Record 32 of Set 6 | stege
# Processing Record 33 of Set 6 | port moresby
# Processing Record 34 of Set 6 | victoria
# Processing Record 35 of Set 6 | saint-augustin
# Processing Record 36 of Set 6 | elk city
# Processing Record 37 of Set 6 | naryan-mar
# Processing Record 38 of Set 6 | lingao
# Processing Record 39 of Set 6 | nanortalik
# Processing Record 40 of Set 6 | palanga
# Processing Record 41 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 6 | okato
# Processing Record 43 of Set 6 | luanda
# Processing Record 44 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 6 | panguna
# Processing Record 46 of Set 6 | kysyl-syr
# Processing Record 47 of Set 6 | iquique
# Processing Record 48 of Set 6 | padang
# Processing Record 49 of Set 6 | steamboat springs
# Processing Record 50 of Set 6 | medea
# Processing Record 1 of Set 7 | new norfolk
# Processing Record 2 of Set 7 | santo antonio do leverger
# Processing Record 3 of Set 7 | korla
# Processing Record 4 of Set 7 | garowe
# Processing Record 5 of Set 7 | tazovskiy
# Processing Record 6 of Set 7 | auchel
# Processing Record 7 of Set 7 | mar del plata
# Processing Record 8 of Set 7 | puerto madryn
# Processing Record 9 of Set 7 | aden
# Processing Record 10 of Set 7 | hualmay
# Processing Record 11 of Set 7 | santa maria
# Processing Record 12 of Set 7 | suarez
# Processing Record 13 of Set 7 | hellvik
# Processing Record 14 of Set 7 | kandrian
# Processing Record 15 of Set 7 | iquitos
# Processing Record 16 of Set 7 | puri
# Processing Record 17 of Set 7 | beloha
# Processing Record 18 of Set 7 | nuuk
# Processing Record 19 of Set 7 | llangefni
# Processing Record 20 of Set 7 | vigrestad
# Processing Record 21 of Set 7 | srednekolymsk
# Processing Record 22 of Set 7 | baiyin
# Processing Record 23 of Set 7 | vila franca do campo
# Processing Record 24 of Set 7 | vallenar
# Processing Record 25 of Set 7 | margate
# Processing Record 26 of Set 7 | japura
# Processing Record 27 of Set 7 | moose factory
# Processing Record 28 of Set 7 | vilyuysk
# Processing Record 29 of Set 7 | burns lake
# Processing Record 30 of Set 7 | yarada
# Processing Record 31 of Set 7 | peace river
# Processing Record 32 of Set 7 | kidal
# Processing Record 33 of Set 7 | lasa
# Processing Record 34 of Set 7 | tuktoyaktuk
# Processing Record 35 of Set 7 | hailun
# Processing Record 36 of Set 7 | pevek
# Processing Record 37 of Set 7 | vardo
# Processing Record 38 of Set 7 | tungkang
# City not found. Skipping...
# Processing Record 39 of Set 7 | geraldton
# Processing Record 40 of Set 7 | brae
# Processing Record 41 of Set 7 | egvekinot
# Processing Record 42 of Set 7 | harper
# Processing Record 43 of Set 7 | isangel
# Processing Record 44 of Set 7 | mbini
# Processing Record 45 of Set 7 | ikom
# Processing Record 46 of Set 7 | volchansk
# Processing Record 47 of Set 7 | qingquan
# Processing Record 48 of Set 7 | kinkala
# Processing Record 49 of Set 7 | belaya gora
# Processing Record 50 of Set 7 | estevan
# Processing Record 1 of Set 8 | la ronge
# Processing Record 2 of Set 8 | panacan
# Processing Record 3 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 4 of Set 8 | tabuk
# Processing Record 5 of Set 8 | burgeo
# Processing Record 6 of Set 8 | carazinho
# Processing Record 7 of Set 8 | dakar
# Processing Record 8 of Set 8 | mega
# Processing Record 9 of Set 8 | xinqing
# Processing Record 10 of Set 8 | tasiilaq
# Processing Record 11 of Set 8 | narsaq
# Processing Record 12 of Set 8 | opuwo
# Processing Record 13 of Set 8 | bengkulu
# Processing Record 14 of Set 8 | koryukivka
# Processing Record 15 of Set 8 | bathsheba
# Processing Record 16 of Set 8 | dovolnoye
# Processing Record 17 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 19 of Set 8 | bajram curri
# Processing Record 20 of Set 8 | cavalcante
# Processing Record 21 of Set 8 | cidreira
# Processing Record 22 of Set 8 | hun
# Processing Record 23 of Set 8 | flinders
# Processing Record 24 of Set 8 | moyo
# Processing Record 25 of Set 8 | tawang
# Processing Record 26 of Set 8 | chacabuco
# Processing Record 27 of Set 8 | onega
# Processing Record 28 of Set 8 | kurumkan
# Processing Record 29 of Set 8 | dubbo
# Processing Record 30 of Set 8 | assis
# Processing Record 31 of Set 8 | kohtla-jarve
# Processing Record 32 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 33 of Set 8 | bonavista
# Processing Record 34 of Set 8 | sao jose da coroa grande
# Processing Record 35 of Set 8 | boa vista
# Processing Record 36 of Set 8 | kapuskasing
# Processing Record 37 of Set 8 | coquimbo
# Processing Record 38 of Set 8 | chokurdakh
# Processing Record 39 of Set 8 | le port
# Processing Record 40 of Set 8 | todos santos
# Processing Record 41 of Set 8 | port-gentil
# Processing Record 42 of Set 8 | san carlos de bariloche
# Processing Record 43 of Set 8 | sept-iles
# Processing Record 44 of Set 8 | ous
# Processing Record 45 of Set 8 | tevaitoa
# Processing Record 46 of Set 8 | moindou
# Processing Record 47 of Set 8 | lenger
# Processing Record 48 of Set 8 | badarpur
# Processing Record 49 of Set 8 | longyearbyen
# Processing Record 50 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 1 of Set 9 | tiganesti
# Processing Record 2 of Set 9 | gaspe
# Processing Record 3 of Set 9 | do gonbadan
# Processing Record 4 of Set 9 | havelock
# Processing Record 5 of Set 9 | linxia
# Processing Record 6 of Set 9 | matay
# Processing Record 7 of Set 9 | atar
# Processing Record 8 of Set 9 | waipawa
# Processing Record 9 of Set 9 | bardiyah
# Processing Record 10 of Set 9 | urengoy
# Processing Record 11 of Set 9 | juba
# Processing Record 12 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 9 | richards bay
# Processing Record 14 of Set 9 | ostrovnoy
# Processing Record 15 of Set 9 | buala
# Processing Record 16 of Set 9 | mahajanga
# Processing Record 17 of Set 9 | shahr-e babak
# Processing Record 18 of Set 9 | mendahara
# City not found. Skipping...
# Processing Record 19 of Set 9 | monroe
# Processing Record 20 of Set 9 | awbari
# Processing Record 21 of Set 9 | manuel doblado
# City not found. Skipping...
# Processing Record 22 of Set 9 | waw
# Processing Record 23 of Set 9 | pochutla
# Processing Record 24 of Set 9 | san francisco
# Processing Record 25 of Set 9 | peleduy
# Processing Record 26 of Set 9 | kurilsk
# Processing Record 27 of Set 9 | kamaishi
# Processing Record 28 of Set 9 | torbay
# Processing Record 29 of Set 9 | mitsamiouli
# Processing Record 30 of Set 9 | sapele
# Processing Record 31 of Set 9 | sabang
# Processing Record 32 of Set 9 | pisco
# Processing Record 33 of Set 9 | arman
# Processing Record 34 of Set 9 | malinyi
# Processing Record 35 of Set 9 | codrington
# Processing Record 36 of Set 9 | yambio
# Processing Record 37 of Set 9 | ginir
# Processing Record 38 of Set 9 | neryungri
# Processing Record 39 of Set 9 | nipawin
# Processing Record 40 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 41 of Set 9 | kainantu
# Processing Record 42 of Set 9 | dali
# Processing Record 43 of Set 9 | vista hermosa
# Processing Record 44 of Set 9 | northam
# Processing Record 45 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 46 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 9 | kaeo
# Processing Record 48 of Set 9 | ambon
# Processing Record 49 of Set 9 | misratah
# Processing Record 50 of Set 9 | antigonish
# Processing Record 1 of Set 10 | sao felix do xingu
# Processing Record 2 of Set 10 | loanda
# Processing Record 3 of Set 10 | linqiong
# Processing Record 4 of Set 10 | palmer
# Processing Record 5 of Set 10 | yeniseysk
# Processing Record 6 of Set 10 | kasulu
# Processing Record 7 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 10 | gasa
# Processing Record 9 of Set 10 | ruwi
# Processing Record 10 of Set 10 | hatta
# Processing Record 11 of Set 10 | anqing
# Processing Record 12 of Set 10 | oranjemund
# Processing Record 13 of Set 10 | boueni
# Processing Record 14 of Set 10 | burladingen
# Processing Record 15 of Set 10 | ostend
# Processing Record 16 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 10 | inhambane
# Processing Record 18 of Set 10 | namatanai
# Processing Record 19 of Set 10 | salinas
# Processing Record 20 of Set 10 | ayame
# Processing Record 21 of Set 10 | koumac
# Processing Record 22 of Set 10 | hokitika
# Processing Record 23 of Set 10 | somerset
# Processing Record 24 of Set 10 | balkanabat
# Processing Record 25 of Set 10 | bedele
# Processing Record 26 of Set 10 | balakhninskiy
# Processing Record 27 of Set 10 | pathein
# Processing Record 28 of Set 10 | faya
# Processing Record 29 of Set 10 | imbituba
# Processing Record 30 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 31 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 10 | salisbury
# Processing Record 33 of Set 10 | andenes
# Processing Record 34 of Set 10 | raudeberg
# Processing Record 35 of Set 10 | muros
# Processing Record 36 of Set 10 | bandarbeyla
# Processing Record 37 of Set 10 | ketchikan
# Processing Record 38 of Set 10 | gzhatsk
# City not found. Skipping...
# Processing Record 39 of Set 10 | skjervoy
# Processing Record 40 of Set 10 | bukama
# Processing Record 41 of Set 10 | yangambi
# Processing Record 42 of Set 10 | ola
# Processing Record 43 of Set 10 | smithers
# Processing Record 44 of Set 10 | kedougou
# Processing Record 45 of Set 10 | gobabis
# Processing Record 46 of Set 10 | khawhai
# Processing Record 47 of Set 10 | newport
# Processing Record 48 of Set 10 | trofors
# Processing Record 49 of Set 10 | san juan evangelista
# Processing Record 50 of Set 10 | kapoeta
# Processing Record 1 of Set 11 | alto baudo
# City not found. Skipping...
# Processing Record 2 of Set 11 | popondetta
# Processing Record 3 of Set 11 | mogadishu
# Processing Record 4 of Set 11 | gurskoye
# City not found. Skipping...
# Processing Record 5 of Set 11 | pringsewu
# Processing Record 6 of Set 11 | san cristobal
# Processing Record 7 of Set 11 | arrifes
# Processing Record 8 of Set 11 | hofn
# Processing Record 9 of Set 11 | mwanza
# Processing Record 10 of Set 11 | bud
# Processing Record 11 of Set 11 | pasni
# Processing Record 12 of Set 11 | costa rica
# Processing Record 13 of Set 11 | saint-joseph
# Processing Record 14 of Set 11 | ponta do sol
# Processing Record 15 of Set 11 | bagn
# Processing Record 16 of Set 11 | naberera
# Processing Record 17 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 11 | cotonou
# Processing Record 20 of Set 11 | loreto
# Processing Record 21 of Set 11 | robe
# Processing Record 22 of Set 11 | clyde river
# Processing Record 23 of Set 11 | itaqui
# Processing Record 24 of Set 11 | nhulunbuy
# Processing Record 25 of Set 11 | lekoni
# Processing Record 26 of Set 11 | porto nacional
# Processing Record 27 of Set 11 | katangli
# Processing Record 28 of Set 11 | colares
# Processing Record 29 of Set 11 | batticaloa
# Processing Record 30 of Set 11 | skegness
# Processing Record 31 of Set 11 | the valley
# Processing Record 32 of Set 11 | pangnirtung
# Processing Record 33 of Set 11 | tornio
# Processing Record 34 of Set 11 | nouakchott
# Processing Record 35 of Set 11 | divnoye
# Processing Record 36 of Set 11 | kalol
# Processing Record 37 of Set 11 | rafaela
# Processing Record 38 of Set 11 | tual
# Processing Record 39 of Set 11 | meulaboh
# Processing Record 40 of Set 11 | mingaora
# Processing Record 41 of Set 11 | nueve de julio
# Processing Record 42 of Set 11 | coos bay
# Processing Record 43 of Set 11 | san patricio
# Processing Record 44 of Set 11 | yining
# Processing Record 45 of Set 11 | upington
# Processing Record 46 of Set 11 | seoni malwa
# Processing Record 47 of Set 11 | pilar
# Processing Record 48 of Set 11 | tuy hoa
# Processing Record 49 of Set 11 | santiago
# Processing Record 50 of Set 11 | mantua
# Processing Record 1 of Set 12 | komarno
# Processing Record 2 of Set 12 | mackay
# Processing Record 3 of Set 12 | aykhal
# Processing Record 4 of Set 12 | half moon bay
# Processing Record 5 of Set 12 | ahuimanu
# Processing Record 6 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 12 | esso
# Processing Record 8 of Set 12 | sayyan
# Processing Record 9 of Set 12 | piskivka
# Processing Record 10 of Set 12 | araouane
# Processing Record 11 of Set 12 | pemangkat
# Processing Record 12 of Set 12 | mosquera
# Processing Record 13 of Set 12 | huai thalaeng
# Processing Record 14 of Set 12 | merauke
# Processing Record 15 of Set 12 | gualeguaychu
# Processing Record 16 of Set 12 | hay river
# Processing Record 17 of Set 12 | bac lieu
# Processing Record 18 of Set 12 | natal
# Processing Record 19 of Set 12 | buzmeyin
# Processing Record 20 of Set 12 | lhokseumawe
# Processing Record 21 of Set 12 | pitkyaranta
# Processing Record 22 of Set 12 | great yarmouth
# Processing Record 23 of Set 12 | rovaniemi
# Processing Record 24 of Set 12 | aksu
# Processing Record 25 of Set 12 | staryy oskol
# Processing Record 26 of Set 12 | nanton
# Processing Record 27 of Set 12 | mount isa
# Processing Record 28 of Set 12 | malanje
# Processing Record 29 of Set 12 | komarikhinskiy
# Processing Record 30 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 31 of Set 12 | tahta
# Processing Record 32 of Set 12 | port hardy
# Processing Record 33 of Set 12 | rawson
# Processing Record 34 of Set 12 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 35 of Set 12 | vostok
# Processing Record 36 of Set 12 | poum
# Processing Record 37 of Set 12 | sinnai
# Processing Record 38 of Set 12 | fairbanks
# Processing Record 39 of Set 12 | polyarnyy
# Processing Record 40 of Set 12 | tabou
# Processing Record 41 of Set 12 | nador
# Processing Record 42 of Set 12 | maniitsoq
# Processing Record 43 of Set 12 | fond du lac
# Processing Record 44 of Set 12 | swellendam
# Processing Record 45 of Set 12 | newcastle
# Processing Record 46 of Set 12 | vagur
# Processing Record 47 of Set 12 | moron
# Processing Record 48 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 49 of Set 12 | puerto escondido
# Processing Record 50 of Set 12 | jaque
# Processing Record 1 of Set 13 | manohar thana
# Processing Record 2 of Set 13 | anshun
# Processing Record 3 of Set 13 | guararapes
# Processing Record 4 of Set 13 | hire
# City not found. Skipping...
# Processing Record 5 of Set 13 | oktyabrskoye
# Processing Record 6 of Set 13 | plettenberg bay
# Processing Record 7 of Set 13 | boca do acre
# Processing Record 8 of Set 13 | maningrida
# Processing Record 9 of Set 13 | vanimo
# Processing Record 10 of Set 13 | tabalosos
# Processing Record 11 of Set 13 | moissala
# Processing Record 12 of Set 13 | zyryanka
# Processing Record 13 of Set 13 | abha
# Processing Record 14 of Set 13 | qarqin
# Processing Record 15 of Set 13 | erdemli
# Processing Record 16 of Set 13 | parian dakula
# Processing Record 17 of Set 13 | camana
# Processing Record 18 of Set 13 | chillicothe
# Processing Record 19 of Set 13 | nago
# Processing Record 20 of Set 13 | dicabisagan
# Processing Record 21 of Set 13 | baruun-urt
# Processing Record 22 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 13 | maldonado
# Processing Record 24 of Set 13 | monterrey
# Processing Record 25 of Set 13 | guerrero negro
# Processing Record 26 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 13 | bolshoye nagatkino
# Processing Record 28 of Set 13 | katobu
# Processing Record 29 of Set 13 | san andres
# Processing Record 30 of Set 13 | maksatikha
# Processing Record 31 of Set 13 | grand gaube
# Processing Record 32 of Set 13 | dores do indaia
# Processing Record 33 of Set 13 | lahaina
# Processing Record 34 of Set 13 | veshenskaya
# Processing Record 35 of Set 13 | gizo
# Processing Record 36 of Set 13 | mae sai
# Processing Record 37 of Set 13 | apatou
# Processing Record 38 of Set 13 | guymon
# Processing Record 39 of Set 13 | san vicente
# Processing Record 40 of Set 13 | udon thani
# Processing Record 41 of Set 13 | galle
# Processing Record 42 of Set 13 | kyra
# Processing Record 43 of Set 13 | grand-lahou
# Processing Record 44 of Set 13 | hearst
# Processing Record 45 of Set 13 | sudak
# Processing Record 46 of Set 13 | temecula
# Processing Record 47 of Set 13 | san rafael del sur
# Processing Record 48 of Set 13 | lexington
# Processing Record 49 of Set 13 | ishigaki
# Processing Record 50 of Set 13 | naze
# Processing Record 1 of Set 14 | jacareacanga
# Processing Record 2 of Set 14 | la asuncion
# Processing Record 3 of Set 14 | batagay-alyta
# Processing Record 4 of Set 14 | xiongyue
# Processing Record 5 of Set 14 | verkhnyaya inta
# Processing Record 6 of Set 14 | turukhansk
# Processing Record 7 of Set 14 | mujiayingzi
# Processing Record 8 of Set 14 | sheffield lake
# Processing Record 9 of Set 14 | yasinya
# Processing Record 10 of Set 14 | khash
# Processing Record 11 of Set 14 | marzuq
# Processing Record 12 of Set 14 | naifaru
# Processing Record 13 of Set 14 | dehui
# Processing Record 14 of Set 14 | show low
# Processing Record 15 of Set 14 | parabel
# Processing Record 16 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 14 | sembakung
# Processing Record 18 of Set 14 | college
# Processing Record 19 of Set 14 | sao gabriel da cachoeira
# Processing Record 20 of Set 14 | oeiras do para
# Processing Record 21 of Set 14 | castres
# Processing Record 22 of Set 14 | bouna
# Processing Record 23 of Set 14 | west odessa
# Processing Record 24 of Set 14 | feijo
# Processing Record 25 of Set 14 | dayong
# Processing Record 26 of Set 14 | saint-louis
# Processing Record 27 of Set 14 | mozarlandia
# Processing Record 28 of Set 14 | muli
# Processing Record 29 of Set 14 | tarazona
# Processing Record 30 of Set 14 | moranbah
# Processing Record 31 of Set 14 | tarakan
# Processing Record 32 of Set 14 | poya
# Processing Record 33 of Set 14 | marystown
# Processing Record 34 of Set 14 | desna
# Processing Record 35 of Set 14 | quatre cocos
# Processing Record 36 of Set 14 | champerico
# Processing Record 37 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 38 of Set 14 | gueugnon
# Processing Record 39 of Set 14 | mandalgovi
# Processing Record 40 of Set 14 | noumea
# Processing Record 41 of Set 14 | penapolis
# Processing Record 42 of Set 14 | takoradi
# Processing Record 43 of Set 14 | vilani
# Processing Record 44 of Set 14 | boguchany
# Processing Record 45 of Set 14 | dudinka
# Processing Record 46 of Set 14 | asfi
# Processing Record 47 of Set 14 | zhanaozen
# Processing Record 48 of Set 14 | stokmarknes
# Processing Record 49 of Set 14 | myskhako
# Processing Record 50 of Set 14 | staryy nadym
# Processing Record 1 of Set 15 | portage lakes
# Processing Record 2 of Set 15 | isla mujeres
# Processing Record 3 of Set 15 | balkhash
# Processing Record 4 of Set 15 | adrar
# Processing Record 5 of Set 15 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 6 of Set 15 | booue
# Processing Record 7 of Set 15 | santa isabel do rio negro
# Processing Record 8 of Set 15 | deputatskiy
# Processing Record 9 of Set 15 | galesong
# Processing Record 10 of Set 15 | balimo
# City not found. Skipping...
# Processing Record 11 of Set 15 | buraydah
# Processing Record 12 of Set 15 | tarrega
# Processing Record 13 of Set 15 | brownfield
# Processing Record 14 of Set 15 | batemans bay
# Processing Record 15 of Set 15 | kavaratti
# Processing Record 16 of Set 15 | abhar
# Processing Record 17 of Set 15 | sumbal
# Processing Record 18 of Set 15 | halifax
# Processing Record 19 of Set 15 | pimentel
# Processing Record 20 of Set 15 | yaan
# Processing Record 21 of Set 15 | safaga
# Processing Record 22 of Set 15 | fort nelson
# Processing Record 23 of Set 15 | saint-michel-des-saints
# Processing Record 24 of Set 15 | xam nua
# Processing Record 25 of Set 15 | tiznit
# Processing Record 26 of Set 15 | talnakh
# Processing Record 27 of Set 15 | arlit
# Processing Record 28 of Set 15 | katiola
# Processing Record 29 of Set 15 | panaba
# Processing Record 30 of Set 15 | namibe
# Processing Record 31 of Set 15 | bandipur
# Processing Record 32 of Set 15 | bizhbulyak
# Processing Record 33 of Set 15 | lorengau
# Processing Record 34 of Set 15 | kirensk
# Processing Record 35 of Set 15 | kovdor
# Processing Record 36 of Set 15 | konstantinovka
# Processing Record 37 of Set 15 | kloulklubed
# Processing Record 38 of Set 15 | nelson bay
# Processing Record 39 of Set 15 | mahanoro
# Processing Record 40 of Set 15 | ornskoldsvik
# Processing Record 41 of Set 15 | labytnangi
# Processing Record 42 of Set 15 | kabinda
# Processing Record 43 of Set 15 | duobao
# Processing Record 44 of Set 15 | bulawayo
# Processing Record 45 of Set 15 | malmesbury
# Processing Record 46 of Set 15 | chengmai
# City not found. Skipping...
# Processing Record 47 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 48 of Set 15 | vrangel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# check length of city_data
len(city_data)
# Out:
# 688

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Nikolskoye      RU  59.7035   30.7861     57.09        83          12
# 1        Portland      US  45.5234 -122.6762     65.53        71         100
# 2         Rikitea      PF -23.1203 -134.9692     72.95        67          82
# 3           Sabak      MY   3.7675  100.9875     81.55        83          66
# 4      Walvis Bay      NA -22.9575   14.5053     52.75        46           0
# 5        Zhigansk      RU  66.7697  123.3711     57.81        53           7
# 6           Vaini      TO -21.2000 -175.2000     78.96        78          75
# 7   Mihai Viteazu      RO  46.5333   23.7500     48.13        93          20
# 8  Vestmannaeyjar      IS  63.4427  -20.2734     49.21        73         100
# 9            Nome      US  64.5011 -165.4064     45.16        81         100
#
#    Wind Speed Current Description
# 0       10.67          few clouds
# 1        4.00     overcast clouds
# 2        9.13       broken clouds
# 3        4.83       broken clouds
# 4       10.36           clear sky
# 5       18.05           clear sky
# 6        5.75       broken clouds
# 7        5.75          few clouds
# 8       17.67     overcast clouds
# 9        9.22     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv("output_data_file", index_label="City_ID")
